# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import tensorflow as tf
import numpy as np
import glob

# ============================
# PATH CONFIGURATION
# ============================
BASE_PATH = "/kaggle/input/unet-data/new_data"

# Define folders for train, validation, and test
TRAIN_IMAGES_DIR = os.path.join(BASE_PATH, "train", "images")
TRAIN_MASKS_DIR = os.path.join(BASE_PATH, "train", "GT_ICM")

VAL_IMAGES_DIR = os.path.join(BASE_PATH, "valid", "images")
VAL_MASKS_DIR = os.path.join(BASE_PATH, "valid", "GT_ICM")

TEST_IMAGES_DIR = os.path.join(BASE_PATH, "test", "images")
TEST_MASKS_DIR = os.path.join(BASE_PATH, "test", "GT_ICM")

# Check if files are loaded correctly
print("Train images:", len(os.listdir(TRAIN_IMAGES_DIR)))
print("Train masks:", len(os.listdir(TRAIN_MASKS_DIR)))
print("Validation images:", len(os.listdir(VAL_IMAGES_DIR)))
print("Validation masks:", len(os.listdir(VAL_MASKS_DIR)))
print("Test images:", len(os.listdir(TEST_IMAGES_DIR)))
print("Test masks:", len(os.listdir(TEST_MASKS_DIR)))

# ============================
# IMAGE LOADING FUNCTIONS
# ============================
IMG_HEIGHT = 256
IMG_WIDTH = 256

def load_image(image_path, mask_path):
    """Load and preprocess a single image-mask pair"""
    # Load image
    image = tf.io.read_file(image_path)
    image = tf.image.decode_bmp(image, channels=3)  # decode as RGB
    image = tf.image.rgb_to_grayscale(image)        # convert to grayscale
    image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH])
    image = tf.cast(image, tf.float32) / 255.0

    # Load mask
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_bmp(mask, channels=3)
    mask = tf.image.rgb_to_grayscale(mask)
    mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH])
    mask = tf.cast(mask, tf.float32) / 255.0
    mask = tf.where(mask > 0.5, 1.0, 0.0)  # binarize

    return image, mask

# ============================
# DATASET CREATION
# ============================
def create_dataset(image_dir, mask_dir, batch_size=8, shuffle=True):
    """Create tf.data dataset for training, validation, or testing"""
    image_paths = sorted(glob.glob(os.path.join(image_dir, "*.bmp")))
    mask_paths = sorted(glob.glob(os.path.join(mask_dir, "*.bmp")))

    print(f"Found {len(image_paths)} images and {len(mask_paths)} masks in {image_dir}")

    dataset = tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
    dataset = dataset.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)

    if shuffle:
        dataset = dataset.shuffle(buffer_size=100)

    return dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)

# ============================
# CREATE DATASETS
# ============================
BATCH_SIZE = 16
train_dataset = create_dataset(TRAIN_IMAGES_DIR, TRAIN_MASKS_DIR, batch_size=BATCH_SIZE)
val_dataset = create_dataset(VAL_IMAGES_DIR, VAL_MASKS_DIR, batch_size=BATCH_SIZE, shuffle=False)
test_dataset = create_dataset(TEST_IMAGES_DIR, TEST_MASKS_DIR, batch_size=1, shuffle=False)
# Out:
# 2025-09-15 20:56:28.653285: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757969788.848483      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757969788.914624      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Train images: 995
# Train masks: 995
# Validation images: 25
# Validation masks: 25
# Test images: 25
# Test masks: 25
# Found 995 images and 995 masks in /kaggle/input/unet-data/new_data/train/images
# I0000 00:00:1757969801.288231      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 25 images and 25 masks in /kaggle/input/unet-data/new_data/valid/images
# Found 25 images and 25 masks in /kaggle/input/unet-data/new_data/test/images

# %%
import matplotlib.pyplot as plt

def show_sample(dataset):
    for images, masks in dataset.take(1):
        for i in range(min(3, images.shape[0])):
            plt.figure(figsize=(8, 4))

            plt.subplot(1, 2, 1)
            plt.imshow(tf.squeeze(images[i]), cmap='gray')
            plt.title('Input Image')
            plt.axis('off')

            plt.subplot(1, 2, 2)
            plt.imshow(tf.squeeze(masks[i]), cmap='gray')
            plt.title('ICM Mask')
            plt.axis('off')

            plt.show()

show_sample(train_dataset)

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model

def unet_model(input_shape=(256, 256, 1)):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D((2, 2))(c4)

    # Bottleneck
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(c5)

    # Decoder
    u6 = layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c6)

    u7 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c7)

    u8 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c8)

    u9 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = layers.concatenate([u9, c1])
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c9)

    # Output layer for **binary segmentation**
    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

    return Model(inputs=[inputs], outputs=[outputs])

# %%
# Dice Coefficient
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

# IoU Metric
def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# BCE + Dice Loss
def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    dice_loss = 1 - dice_coefficient(y_true, y_pred)
    return bce + dice_loss

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

EPOCHS = 100
BATCH_SIZE = 16

# Build U-Net model
model = unet_model(input_shape=(256, 256, 1))
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=bce_dice_loss,
    metrics=['accuracy', dice_coefficient, iou_metric]
)

# Callbacks
early_stopping = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=10,
    mode='max',
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "best_model.h5",
    monitor='val_dice_coefficient',
    save_best_only=True,
    mode='max'
)

# Train the model
history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=EPOCHS,
    callbacks=[early_stopping, checkpoint],
    verbose=1 
)# <-- makes sure metrics are shown
# Out:
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 256, 256, 1))
#   warnings.warn(msg)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1757969838.532881      98 service.cc:148] XLA service 0x7bbff000a1a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1757969838.534409      98 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1757969839.499754      98 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1757969874.979373      98 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 62/63 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.8529 - dice_coefficient: 0.1279 - iou_metric: 0.0686 - loss: 1.3895
# E0000 00:00:1757969898.682675      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1757969898.938568      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 529ms/step - accuracy: 0.8538 - dice_coefficient: 0.1276 - iou_metric: 0.0684 - loss: 1.3877
# E0000 00:00:1757969922.587681      96 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1757969922.823179      96 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1757969923.504328      96 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1757969923.762877      96 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 100s 879ms/step - accuracy: 0.8546 - dice_coefficient: 0.1273 - iou_metric: 0.0683 - loss: 1.3858 - val_accuracy: 0.9184 - val_dice_coefficient: 0.1130 - val_iou_metric: 0.0599 - val_loss: 1.1554
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 23s 369ms/step - accuracy: 0.9129 - dice_coefficient: 0.1930 - iou_metric: 0.1090 - loss: 1.0613 - val_accuracy: 0.9327 - val_dice_coefficient: 0.3444 - val_iou_metric: 0.2081 - val_loss: 0.8460
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 23s 369ms/step - accuracy: 0.9038 - dice_coefficient: 0.4053 - iou_metric: 0.2555 - loss: 0.7978 - val_accuracy: 0.9062 - val_dice_coefficient: 0.4125 - val_iou_metric: 0.2601 - val_loss: 0.7715
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 23s 370ms/step - accuracy: 0.9294 - dice_coefficient: 0.5349 - iou_metric: 0.3672 - loss: 0.6515 - val_accuracy: 0.9247 - val_dice_coefficient: 0.5922 - val_iou_metric: 0.4207 - val_loss: 0.6241
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 23s 369ms/step - accuracy: 0.9416 - dice_coefficient: 0.6216 - iou_metric: 0.4547 - loss: 0.5508 - val_accuracy: 0.9235 - val_dice_coefficient: 0.5985 - val_iou_metric: 0.4271 - val_loss: 0.5799
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 23s 370ms/step - accuracy: 0.9531 - dice_coefficient: 0.7032 - iou_metric: 0.5443 - loss: 0.4349 - val_accuracy: 0.9461 - val_dice_coefficient: 0.6597 - val_iou_metric: 0.4922 - val_loss: 0.4799
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9560 - dice_coefficient: 0.7013 - iou_metric: 0.5429 - loss: 0.4283 - val_accuracy: 0.9312 - val_dice_coefficient: 0.6078 - val_iou_metric: 0.4366 - val_loss: 0.5668
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9527 - dice_coefficient: 0.6951 - iou_metric: 0.5351 - loss: 0.4480 - val_accuracy: 0.9251 - val_dice_coefficient: 0.6100 - val_iou_metric: 0.4390 - val_loss: 0.5781
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9568 - dice_coefficient: 0.7257 - iou_metric: 0.5729 - loss: 0.4014 - val_accuracy: 0.9482 - val_dice_coefficient: 0.6532 - val_iou_metric: 0.4850 - val_loss: 0.4921
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 24s 371ms/step - accuracy: 0.9603 - dice_coefficient: 0.7361 - iou_metric: 0.5849 - loss: 0.3815 - val_accuracy: 0.9599 - val_dice_coefficient: 0.7173 - val_iou_metric: 0.5594 - val_loss: 0.3984
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 23s 371ms/step - accuracy: 0.9643 - dice_coefficient: 0.7578 - iou_metric: 0.6122 - loss: 0.3489 - val_accuracy: 0.9642 - val_dice_coefficient: 0.7413 - val_iou_metric: 0.5890 - val_loss: 0.3625
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9670 - dice_coefficient: 0.7750 - iou_metric: 0.6341 - loss: 0.3212 - val_accuracy: 0.9310 - val_dice_coefficient: 0.6598 - val_iou_metric: 0.4928 - val_loss: 0.5350
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 24s 372ms/step - accuracy: 0.9594 - dice_coefficient: 0.7505 - iou_metric: 0.6046 - loss: 0.3686 - val_accuracy: 0.9618 - val_dice_coefficient: 0.7539 - val_iou_metric: 0.6055 - val_loss: 0.3576
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 24s 372ms/step - accuracy: 0.9680 - dice_coefficient: 0.7840 - iou_metric: 0.6464 - loss: 0.3085 - val_accuracy: 0.9676 - val_dice_coefficient: 0.7547 - val_iou_metric: 0.6066 - val_loss: 0.3365
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 24s 371ms/step - accuracy: 0.9718 - dice_coefficient: 0.7944 - iou_metric: 0.6611 - loss: 0.2897 - val_accuracy: 0.9647 - val_dice_coefficient: 0.7764 - val_iou_metric: 0.6352 - val_loss: 0.3265
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 352ms/step - accuracy: 0.9730 - dice_coefficient: 0.8160 - iou_metric: 0.6905 - loss: 0.2625 - val_accuracy: 0.9658 - val_dice_coefficient: 0.7755 - val_iou_metric: 0.6336 - val_loss: 0.3232
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 352ms/step - accuracy: 0.9732 - dice_coefficient: 0.8090 - iou_metric: 0.6810 - loss: 0.2697 - val_accuracy: 0.9605 - val_dice_coefficient: 0.7698 - val_iou_metric: 0.6264 - val_loss: 0.3526
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 24s 371ms/step - accuracy: 0.9738 - dice_coefficient: 0.8231 - iou_metric: 0.7013 - loss: 0.2533 - val_accuracy: 0.9719 - val_dice_coefficient: 0.8091 - val_iou_metric: 0.6796 - val_loss: 0.2780
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 352ms/step - accuracy: 0.9770 - dice_coefficient: 0.8415 - iou_metric: 0.7274 - loss: 0.2267 - val_accuracy: 0.9674 - val_dice_coefficient: 0.8022 - val_iou_metric: 0.6704 - val_loss: 0.3036
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9770 - dice_coefficient: 0.8453 - iou_metric: 0.7333 - loss: 0.2233 - val_accuracy: 0.9571 - val_dice_coefficient: 0.7642 - val_iou_metric: 0.6190 - val_loss: 0.3797
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9745 - dice_coefficient: 0.8296 - iou_metric: 0.7101 - loss: 0.2485 - val_accuracy: 0.8494 - val_dice_coefficient: 0.4737 - val_iou_metric: 0.3105 - val_loss: 0.8900
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 352ms/step - accuracy: 0.9597 - dice_coefficient: 0.7698 - iou_metric: 0.6359 - loss: 0.3403 - val_accuracy: 0.9708 - val_dice_coefficient: 0.8019 - val_iou_metric: 0.6695 - val_loss: 0.2834
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9777 - dice_coefficient: 0.8491 - iou_metric: 0.7384 - loss: 0.2180 - val_accuracy: 0.9715 - val_dice_coefficient: 0.8058 - val_iou_metric: 0.6749 - val_loss: 0.2754
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9787 - dice_coefficient: 0.8528 - iou_metric: 0.7443 - loss: 0.2110 - val_accuracy: 0.9726 - val_dice_coefficient: 0.8059 - val_iou_metric: 0.6750 - val_loss: 0.2733
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 23s 371ms/step - accuracy: 0.9803 - dice_coefficient: 0.8641 - iou_metric: 0.7615 - loss: 0.1952 - val_accuracy: 0.9729 - val_dice_coefficient: 0.8141 - val_iou_metric: 0.6867 - val_loss: 0.2692
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 352ms/step - accuracy: 0.9810 - dice_coefficient: 0.8651 - iou_metric: 0.7630 - loss: 0.1934 - val_accuracy: 0.9692 - val_dice_coefficient: 0.7972 - val_iou_metric: 0.6629 - val_loss: 0.2942
# Epoch 27/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 24s 372ms/step - accuracy: 0.9811 - dice_coefficient: 0.8714 - iou_metric: 0.7730 - loss: 0.1859 - val_accuracy: 0.9746 - val_dice_coefficient: 0.8222 - val_iou_metric: 0.6982 - val_loss: 0.2585
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 24s 371ms/step - accuracy: 0.9838 - dice_coefficient: 0.8862 - iou_metric: 0.7964 - loss: 0.1642 - val_accuracy: 0.9753 - val_dice_coefficient: 0.8268 - val_iou_metric: 0.7049 - val_loss: 0.2538
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 352ms/step - accuracy: 0.9845 - dice_coefficient: 0.8923 - iou_metric: 0.8060 - loss: 0.1563 - val_accuracy: 0.9648 - val_dice_coefficient: 0.7880 - val_iou_metric: 0.6504 - val_loss: 0.3254
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9827 - dice_coefficient: 0.8820 - iou_metric: 0.7901 - loss: 0.1707 - val_accuracy: 0.9675 - val_dice_coefficient: 0.8054 - val_iou_metric: 0.6745 - val_loss: 0.3061
# Epoch 31/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 352ms/step - accuracy: 0.9835 - dice_coefficient: 0.8880 - iou_metric: 0.7995 - loss: 0.1628 - val_accuracy: 0.9731 - val_dice_coefficient: 0.8147 - val_iou_metric: 0.6873 - val_loss: 0.2750
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 352ms/step - accuracy: 0.9863 - dice_coefficient: 0.9035 - iou_metric: 0.8244 - loss: 0.1401 - val_accuracy: 0.9704 - val_dice_coefficient: 0.8135 - val_iou_metric: 0.6861 - val_loss: 0.2851
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9867 - dice_coefficient: 0.9088 - iou_metric: 0.8334 - loss: 0.1328 - val_accuracy: 0.9729 - val_dice_coefficient: 0.8243 - val_iou_metric: 0.7013 - val_loss: 0.2732
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9869 - dice_coefficient: 0.9112 - iou_metric: 0.8374 - loss: 0.1305 - val_accuracy: 0.9668 - val_dice_coefficient: 0.7870 - val_iou_metric: 0.6490 - val_loss: 0.3210
# Epoch 35/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9858 - dice_coefficient: 0.9046 - iou_metric: 0.8262 - loss: 0.1405 - val_accuracy: 0.9682 - val_dice_coefficient: 0.7889 - val_iou_metric: 0.6518 - val_loss: 0.3103
# Epoch 36/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9859 - dice_coefficient: 0.9047 - iou_metric: 0.8267 - loss: 0.1400 - val_accuracy: 0.9714 - val_dice_coefficient: 0.8066 - val_iou_metric: 0.6758 - val_loss: 0.2909
# Epoch 37/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9877 - dice_coefficient: 0.9163 - iou_metric: 0.8459 - loss: 0.1224 - val_accuracy: 0.9689 - val_dice_coefficient: 0.7974 - val_iou_metric: 0.6631 - val_loss: 0.3115
# Epoch 38/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 22s 351ms/step - accuracy: 0.9886 - dice_coefficient: 0.9214 - iou_metric: 0.8548 - loss: 0.1148 - val_accuracy: 0.9701 - val_dice_coefficient: 0.7955 - val_iou_metric: 0.6606 - val_loss: 0.3222

# %%
import matplotlib.pyplot as plt

def plot_metrics(history):
    # Dice
    plt.figure(figsize=(10,4))
    plt.plot(history.history['dice_coefficient'], label='Train Dice')
    plt.plot(history.history['val_dice_coefficient'], label='Val Dice')
    plt.title('Dice Coefficient')
    plt.xlabel('Epoch')
    plt.ylabel('Dice')
    plt.legend()
    plt.show()

    # IoU
    plt.figure(figsize=(10,4))
    plt.plot(history.history['iou_metric'], label='Train IoU')
    plt.plot(history.history['val_iou_metric'], label='Val IoU')
    plt.title('IoU Metric')
    plt.xlabel('Epoch')
    plt.ylabel('IoU')
    plt.legend()
    plt.show()

plot_metrics(history)

# %%
# Load best model
model.load_weights("best_model.h5")

# Evaluate on test set
results = model.evaluate(test_dataset)
print("\nTest Results:")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.4f}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9765 - dice_coefficient: 0.8145 - iou_metric: 0.6964 - loss: 0.2543
#
# Test Results:
# loss: 0.2283
# compile_metrics: 0.9783

# %%
import matplotlib.pyplot as plt

def display_predictions(model, dataset, num_samples=5):
    for images, masks in dataset.take(num_samples):
        preds = model.predict(images)
        preds = (preds > 0.5).astype("float32")  # Binarize predictions

        for i in range(len(images)):
            plt.figure(figsize=(12, 4))

            plt.subplot(1, 3, 1)
            plt.title("Input Image")
            plt.imshow(images[i].numpy().squeeze(), cmap="gray")
            plt.axis("off")

            plt.subplot(1, 3, 2)
            plt.title("Ground Truth")
            plt.imshow(masks[i].numpy().squeeze(), cmap="gray")
            plt.axis("off")

            plt.subplot(1, 3, 3)
            plt.title("Prediction")
            plt.imshow(preds[i].squeeze(), cmap="gray")
            plt.axis("off")

            plt.show()

# Show predictions for test samples
display_predictions(model, test_dataset, num_samples=5)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(1, 256, 256, 1))
#   warnings.warn(msg)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 860ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
