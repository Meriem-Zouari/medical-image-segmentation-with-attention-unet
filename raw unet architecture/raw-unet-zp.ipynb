# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
import tensorflow as tf
import numpy as np
import glob

BASE_PATH = "/kaggle/input/dataset/new_data"

# Define folders for train, validation, and test
TRAIN_IMAGES_DIR = os.path.join(BASE_PATH, "train", "images")
TRAIN_MASKS_DIR = os.path.join(BASE_PATH, "train", "GT_ZP")

VAL_IMAGES_DIR = os.path.join(BASE_PATH, "valid", "images")
VAL_MASKS_DIR = os.path.join(BASE_PATH, "valid", "GT_ZP")

TEST_IMAGES_DIR = os.path.join(BASE_PATH, "test", "images")
TEST_MASKS_DIR = os.path.join(BASE_PATH, "test", "GT_ZP")

# Check if files are loaded correctly
print("Train images:", len(os.listdir(TRAIN_IMAGES_DIR)))
print("Train masks:", len(os.listdir(TRAIN_MASKS_DIR)))
print("Validation images:", len(os.listdir(VAL_IMAGES_DIR)))
print("Validation masks:", len(os.listdir(VAL_MASKS_DIR)))
print("Test images:", len(os.listdir(TEST_IMAGES_DIR)))
print("Test masks:", len(os.listdir(TEST_MASKS_DIR)))



IMG_HEIGHT = 256
IMG_WIDTH = 256


def load_image(image_path, mask_path):
    """Load and preprocess a single image-mask pair"""
    # Load image
    image = tf.io.read_file(image_path)
    image = tf.image.decode_bmp(image, channels=3)  # decode as RGB
    image = tf.image.rgb_to_grayscale(image)        # convert to grayscale
    image = tf.image.resize(image, [IMG_HEIGHT, IMG_WIDTH])
    image = tf.cast(image, tf.float32) / 255.0

    # Load mask
    mask = tf.io.read_file(mask_path)
    mask = tf.image.decode_bmp(mask, channels=3)
    mask = tf.image.rgb_to_grayscale(mask)
    mask = tf.image.resize(mask, [IMG_HEIGHT, IMG_WIDTH])
    mask = tf.cast(mask, tf.float32) / 255.0
    mask = tf.where(mask > 0.5, 1.0, 0.0)  # binarize

    return image, mask

def create_dataset(image_dir, mask_dir, batch_size=8, shuffle=True):
    """Create tf.data dataset for training, validation, or testing"""
    image_paths = sorted(glob.glob(os.path.join(image_dir, "*.bmp")))
    mask_paths = sorted(glob.glob(os.path.join(mask_dir, "*.bmp")))

    print(f"Found {len(image_paths)} images and {len(mask_paths)} masks in {image_dir}")

    dataset = tf.data.Dataset.from_tensor_slices((image_paths, mask_paths))
    dataset = dataset.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)

    if shuffle:
        dataset = dataset.shuffle(buffer_size=100)

    return dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)



BATCH_SIZE = 16
train_dataset = create_dataset(TRAIN_IMAGES_DIR, TRAIN_MASKS_DIR, batch_size=BATCH_SIZE)
val_dataset = create_dataset(VAL_IMAGES_DIR, VAL_MASKS_DIR, batch_size=BATCH_SIZE, shuffle=False)
test_dataset = create_dataset(TEST_IMAGES_DIR, TEST_MASKS_DIR, batch_size=1, shuffle=False)
# Out:
# 2025-09-15 21:57:26.093206: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757973446.339446      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757973446.412131      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Train images: 995
# Train masks: 995
# Validation images: 25
# Validation masks: 25
# Test images: 25
# Test masks: 25
# Found 995 images and 995 masks in /kaggle/input/dataset/new_data/train/images
# I0000 00:00:1757973460.814326      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Found 25 images and 25 masks in /kaggle/input/dataset/new_data/valid/images
# Found 25 images and 25 masks in /kaggle/input/dataset/new_data/test/images

# %%
import matplotlib.pyplot as plt

def show_sample(dataset):
    for images, masks in dataset.take(1):
        for i in range(min(3, images.shape[0])):
            plt.figure(figsize=(8, 4))<

            plt.subplot(1, 2, 1)
            plt.imshow(tf.squeeze(images[i]), cmap='gray')
            plt.title('Input Image')
            plt.axis('off')

            plt.subplot(1, 2, 2)
            plt.imshow(tf.squeeze(masks[i]), cmap='gray')
            plt.title('ZP Mask')
            plt.axis('off')

            plt.show()

show_sample(train_dataset)

# %%
import tensorflow as tf
from tensorflow.keras import layers, Model

def unet_model(input_shape=(256, 256, 1)):
    inputs = layers.Input(shape=input_shape)

    # Encoder
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D((2, 2))(c1)

    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D((2, 2))(c2)

    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c3)
    p3 = layers.MaxPooling2D((2, 2))(c3)

    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(p3)
    c4 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c4)
    p4 = layers.MaxPooling2D((2, 2))(c4)

    # Bottleneck
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(p4)
    c5 = layers.Conv2D(1024, (3, 3), activation='relu', padding='same')(c5)

    # Decoder
    u6 = layers.Conv2DTranspose(512, (2, 2), strides=(2, 2), padding='same')(c5)
    u6 = layers.concatenate([u6, c4])
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(u6)
    c6 = layers.Conv2D(512, (3, 3), activation='relu', padding='same')(c6)

    u7 = layers.Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(c6)
    u7 = layers.concatenate([u7, c3])
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(u7)
    c7 = layers.Conv2D(256, (3, 3), activation='relu', padding='same')(c7)

    u8 = layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c7)
    u8 = layers.concatenate([u8, c2])
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(u8)
    c8 = layers.Conv2D(128, (3, 3), activation='relu', padding='same')(c8)

    u9 = layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(c8)
    u9 = layers.concatenate([u9, c1])
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(u9)
    c9 = layers.Conv2D(64, (3, 3), activation='relu', padding='same')(c9)

    # Output layer for **binary segmentation**
    outputs = layers.Conv2D(1, (1, 1), activation='sigmoid')(c9)

    return Model(inputs=[inputs], outputs=[outputs])

# %%
# Dice Coefficient
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + smooth)

# IoU Metric
def iou_metric(y_true, y_pred, smooth=1e-6):
    y_true_f = tf.keras.backend.flatten(y_true)
    y_pred_f = tf.keras.backend.flatten(y_pred)
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    union = tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) - intersection
    return (intersection + smooth) / (union + smooth)

# BCE + Dice Loss
def bce_dice_loss(y_true, y_pred):
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    dice_loss = 1 - dice_coefficient(y_true, y_pred)
    return bce + dice_loss

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stopping = EarlyStopping(
    monitor='val_dice_coefficient',
    patience=10,
    mode='max',
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "best_model.h5",
    monitor='val_dice_coefficient',
    save_best_only=True,
    mode='max'
)

# %%
from sklearn.model_selection import KFold
import numpy as np

# === Gather image and mask paths ===
image_paths = sorted(glob.glob(os.path.join(TRAIN_IMAGES_DIR, "*.bmp")))
mask_paths = sorted(glob.glob(os.path.join(TRAIN_MASKS_DIR, "*.bmp")))

# Convert lists to numpy arrays for easier indexing during cross-validation
image_paths = np.array(image_paths)
mask_paths = np.array(mask_paths)

# === Create K-Fold cross-validator ===
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# %%
EPOCHS = 100
BATCH_SIZE = 8

fold_num = 1
for train_idx, val_idx in kfold.split(image_paths):
    print(f"\n--- Fold {fold_num} ---")

    # Split data
    train_images = image_paths[train_idx]
    train_masks = mask_paths[train_idx]
    val_images = image_paths[val_idx]
    val_masks = mask_paths[val_idx]

    # Create datasets
    def dataset_from_paths(images, masks, shuffle=True):
        dataset = tf.data.Dataset.from_tensor_slices((images, masks))
        dataset = dataset.map(load_image, num_parallel_calls=tf.data.AUTOTUNE)
        if shuffle:
            dataset = dataset.shuffle(100)
        return dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

    train_dataset = dataset_from_paths(train_images, train_masks, shuffle=True)
    val_dataset = dataset_from_paths(val_images, val_masks, shuffle=False)

    # Build U-Net model
    model = unet_model(input_shape=(256, 256, 1))
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
        loss=bce_dice_loss,
        metrics=['accuracy', dice_coefficient, iou_metric]
    )

    # Train model

    history = model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=EPOCHS,
        callbacks=[early_stopping, checkpoint]
    )


    fold_num += 1
# Out:
# --- Fold 1 ---
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 256, 256, 1))
#   warnings.warn(msg)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1757973672.998267     100 service.cc:148] XLA service 0x79ed88008a90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1757973672.999443     100 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1757973674.009453     100 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1757973694.860349     100 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  99/100 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - accuracy: 0.7793 - dice_coefficient: 0.2014 - iou_metric: 0.1124 - loss: 1.3381
# E0000 00:00:1757973717.094828     101 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1757973717.351602     101 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0.7798 - dice_coefficient: 0.2012 - iou_metric: 0.1123 - loss: 1.3375
# E0000 00:00:1757973739.250461      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1757973739.489495      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1757973739.724034      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1757973740.345661      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# E0000 00:00:1757973740.603277      98 gpu_timer.cc:82] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 82s 513ms/step - accuracy: 0.7804 - dice_coefficient: 0.2011 - iou_metric: 0.1123 - loss: 1.3370 - val_accuracy: 0.8457 - val_dice_coefficient: 0.2041 - val_iou_metric: 0.1138 - val_loss: 1.2189
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 228ms/step - accuracy: 0.8471 - dice_coefficient: 0.2762 - iou_metric: 0.1621 - loss: 1.1090 - val_accuracy: 0.8570 - val_dice_coefficient: 0.4694 - val_iou_metric: 0.3078 - val_loss: 0.9680
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 227ms/step - accuracy: 0.8938 - dice_coefficient: 0.6167 - iou_metric: 0.4501 - loss: 0.6522 - val_accuracy: 0.9233 - val_dice_coefficient: 0.6999 - val_iou_metric: 0.5411 - val_loss: 0.4916
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 228ms/step - accuracy: 0.9249 - dice_coefficient: 0.7180 - iou_metric: 0.5613 - loss: 0.4762 - val_accuracy: 0.9238 - val_dice_coefficient: 0.7019 - val_iou_metric: 0.5431 - val_loss: 0.4932
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 229ms/step - accuracy: 0.9303 - dice_coefficient: 0.7397 - iou_metric: 0.5883 - loss: 0.4413 - val_accuracy: 0.9298 - val_dice_coefficient: 0.7209 - val_iou_metric: 0.5661 - val_loss: 0.4557
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 229ms/step - accuracy: 0.9326 - dice_coefficient: 0.7450 - iou_metric: 0.5955 - loss: 0.4300 - val_accuracy: 0.9320 - val_dice_coefficient: 0.7437 - val_iou_metric: 0.5948 - val_loss: 0.4298
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 217ms/step - accuracy: 0.9358 - dice_coefficient: 0.7577 - iou_metric: 0.6111 - loss: 0.4105 - val_accuracy: 0.9367 - val_dice_coefficient: 0.7379 - val_iou_metric: 0.5874 - val_loss: 0.4303
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 217ms/step - accuracy: 0.9380 - dice_coefficient: 0.7669 - iou_metric: 0.6232 - loss: 0.3956 - val_accuracy: 0.9353 - val_dice_coefficient: 0.7114 - val_iou_metric: 0.5546 - val_loss: 0.4589
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 230ms/step - accuracy: 0.9392 - dice_coefficient: 0.7689 - iou_metric: 0.6256 - loss: 0.3898 - val_accuracy: 0.9359 - val_dice_coefficient: 0.7604 - val_iou_metric: 0.6167 - val_loss: 0.4158
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 230ms/step - accuracy: 0.9414 - dice_coefficient: 0.7811 - iou_metric: 0.6421 - loss: 0.3722 - val_accuracy: 0.9418 - val_dice_coefficient: 0.7729 - val_iou_metric: 0.6333 - val_loss: 0.3930
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9438 - dice_coefficient: 0.7887 - iou_metric: 0.6522 - loss: 0.3590 - val_accuracy: 0.9413 - val_dice_coefficient: 0.7657 - val_iou_metric: 0.6236 - val_loss: 0.3970
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9476 - dice_coefficient: 0.7993 - iou_metric: 0.6668 - loss: 0.3390 - val_accuracy: 0.9475 - val_dice_coefficient: 0.7856 - val_iou_metric: 0.6502 - val_loss: 0.3569
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9520 - dice_coefficient: 0.8163 - iou_metric: 0.6908 - loss: 0.3114 - val_accuracy: 0.9484 - val_dice_coefficient: 0.7855 - val_iou_metric: 0.6502 - val_loss: 0.3524
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9544 - dice_coefficient: 0.8225 - iou_metric: 0.6996 - loss: 0.2974 - val_accuracy: 0.9517 - val_dice_coefficient: 0.8036 - val_iou_metric: 0.6753 - val_loss: 0.3295
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9572 - dice_coefficient: 0.8352 - iou_metric: 0.7179 - loss: 0.2777 - val_accuracy: 0.9539 - val_dice_coefficient: 0.8090 - val_iou_metric: 0.6827 - val_loss: 0.3230
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 230ms/step - accuracy: 0.9597 - dice_coefficient: 0.8436 - iou_metric: 0.7305 - loss: 0.2645 - val_accuracy: 0.9528 - val_dice_coefficient: 0.8281 - val_iou_metric: 0.7107 - val_loss: 0.3081
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9610 - dice_coefficient: 0.8514 - iou_metric: 0.7421 - loss: 0.2522 - val_accuracy: 0.9553 - val_dice_coefficient: 0.8162 - val_iou_metric: 0.6932 - val_loss: 0.3071
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9640 - dice_coefficient: 0.8610 - iou_metric: 0.7568 - loss: 0.2354 - val_accuracy: 0.9559 - val_dice_coefficient: 0.8327 - val_iou_metric: 0.7173 - val_loss: 0.3006
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9643 - dice_coefficient: 0.8634 - iou_metric: 0.7607 - loss: 0.2331 - val_accuracy: 0.9565 - val_dice_coefficient: 0.8278 - val_iou_metric: 0.7101 - val_loss: 0.2957
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9657 - dice_coefficient: 0.8674 - iou_metric: 0.7669 - loss: 0.2259 - val_accuracy: 0.9547 - val_dice_coefficient: 0.8292 - val_iou_metric: 0.7124 - val_loss: 0.2946
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9648 - dice_coefficient: 0.8652 - iou_metric: 0.7634 - loss: 0.2300 - val_accuracy: 0.9591 - val_dice_coefficient: 0.8230 - val_iou_metric: 0.7025 - val_loss: 0.2873
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9673 - dice_coefficient: 0.8747 - iou_metric: 0.7781 - loss: 0.2136 - val_accuracy: 0.9526 - val_dice_coefficient: 0.8324 - val_iou_metric: 0.7173 - val_loss: 0.3059
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9669 - dice_coefficient: 0.8747 - iou_metric: 0.7782 - loss: 0.2162 - val_accuracy: 0.9582 - val_dice_coefficient: 0.8255 - val_iou_metric: 0.7064 - val_loss: 0.2884
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9685 - dice_coefficient: 0.8787 - iou_metric: 0.7849 - loss: 0.2062 - val_accuracy: 0.9444 - val_dice_coefficient: 0.7744 - val_iou_metric: 0.6352 - val_loss: 0.3901
# Epoch 25/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9662 - dice_coefficient: 0.8717 - iou_metric: 0.7736 - loss: 0.2193 - val_accuracy: 0.9561 - val_dice_coefficient: 0.8344 - val_iou_metric: 0.7202 - val_loss: 0.2870
# Epoch 26/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9698 - dice_coefficient: 0.8851 - iou_metric: 0.7946 - loss: 0.1964 - val_accuracy: 0.9581 - val_dice_coefficient: 0.8369 - val_iou_metric: 0.7233 - val_loss: 0.2818
# Epoch 27/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9702 - dice_coefficient: 0.8868 - iou_metric: 0.7973 - loss: 0.1942 - val_accuracy: 0.9557 - val_dice_coefficient: 0.8180 - val_iou_metric: 0.6957 - val_loss: 0.3115
# Epoch 28/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9697 - dice_coefficient: 0.8840 - iou_metric: 0.7930 - loss: 0.1986 - val_accuracy: 0.9570 - val_dice_coefficient: 0.8296 - val_iou_metric: 0.7126 - val_loss: 0.2924
# Epoch 29/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9707 - dice_coefficient: 0.8882 - iou_metric: 0.7997 - loss: 0.1913 - val_accuracy: 0.9581 - val_dice_coefficient: 0.8250 - val_iou_metric: 0.7054 - val_loss: 0.2900
# Epoch 30/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9716 - dice_coefficient: 0.8893 - iou_metric: 0.8015 - loss: 0.1869 - val_accuracy: 0.9565 - val_dice_coefficient: 0.8335 - val_iou_metric: 0.7187 - val_loss: 0.3012
# Epoch 31/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9715 - dice_coefficient: 0.8895 - iou_metric: 0.8017 - loss: 0.1873 - val_accuracy: 0.9594 - val_dice_coefficient: 0.8376 - val_iou_metric: 0.7238 - val_loss: 0.2834
# Epoch 32/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9734 - dice_coefficient: 0.8971 - iou_metric: 0.8142 - loss: 0.1749 - val_accuracy: 0.9608 - val_dice_coefficient: 0.8470 - val_iou_metric: 0.7384 - val_loss: 0.2707
# Epoch 33/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9741 - dice_coefficient: 0.9008 - iou_metric: 0.8201 - loss: 0.1696 - val_accuracy: 0.9581 - val_dice_coefficient: 0.8351 - val_iou_metric: 0.7205 - val_loss: 0.2842
# Epoch 34/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9746 - dice_coefficient: 0.9008 - iou_metric: 0.8201 - loss: 0.1684 - val_accuracy: 0.9593 - val_dice_coefficient: 0.8441 - val_iou_metric: 0.7339 - val_loss: 0.2774
# Epoch 35/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9748 - dice_coefficient: 0.9027 - iou_metric: 0.8233 - loss: 0.1654 - val_accuracy: 0.9597 - val_dice_coefficient: 0.8519 - val_iou_metric: 0.7457 - val_loss: 0.2718
# Epoch 36/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9762 - dice_coefficient: 0.9087 - iou_metric: 0.8331 - loss: 0.1562 - val_accuracy: 0.9588 - val_dice_coefficient: 0.8504 - val_iou_metric: 0.7436 - val_loss: 0.2781
# Epoch 37/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9771 - dice_coefficient: 0.9129 - iou_metric: 0.8401 - loss: 0.1490 - val_accuracy: 0.9587 - val_dice_coefficient: 0.8431 - val_iou_metric: 0.7320 - val_loss: 0.2831
# Epoch 38/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9773 - dice_coefficient: 0.9109 - iou_metric: 0.8369 - loss: 0.1495 - val_accuracy: 0.9596 - val_dice_coefficient: 0.8498 - val_iou_metric: 0.7417 - val_loss: 0.2894
# Epoch 39/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9790 - dice_coefficient: 0.9200 - iou_metric: 0.8522 - loss: 0.1364 - val_accuracy: 0.9563 - val_dice_coefficient: 0.8399 - val_iou_metric: 0.7274 - val_loss: 0.3120
# Epoch 40/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.9796 - dice_coefficient: 0.9216 - iou_metric: 0.8550 - loss: 0.1328 - val_accuracy: 0.9605 - val_dice_coefficient: 0.8574 - val_iou_metric: 0.7540 - val_loss: 0.2812
# Epoch 41/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 233ms/step - accuracy: 0.9812 - dice_coefficient: 0.9266 - iou_metric: 0.8636 - loss: 0.1235 - val_accuracy: 0.9615 - val_dice_coefficient: 0.8577 - val_iou_metric: 0.7543 - val_loss: 0.2765
# Epoch 42/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9817 - dice_coefficient: 0.9288 - iou_metric: 0.8672 - loss: 0.1198 - val_accuracy: 0.9599 - val_dice_coefficient: 0.8537 - val_iou_metric: 0.7481 - val_loss: 0.2848
# Epoch 43/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.9818 - dice_coefficient: 0.9287 - iou_metric: 0.8673 - loss: 0.1194 - val_accuracy: 0.9612 - val_dice_coefficient: 0.8603 - val_iou_metric: 0.7581 - val_loss: 0.2885
# Epoch 44/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 233ms/step - accuracy: 0.9837 - dice_coefficient: 0.9370 - iou_metric: 0.8817 - loss: 0.1061 - val_accuracy: 0.9619 - val_dice_coefficient: 0.8676 - val_iou_metric: 0.7699 - val_loss: 0.2983
# Epoch 45/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 223ms/step - accuracy: 0.9840 - dice_coefficient: 0.9394 - iou_metric: 0.8859 - loss: 0.1032 - val_accuracy: 0.9623 - val_dice_coefficient: 0.8669 - val_iou_metric: 0.7683 - val_loss: 0.2973
# Epoch 46/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.9853 - dice_coefficient: 0.9433 - iou_metric: 0.8929 - loss: 0.0961 - val_accuracy: 0.9620 - val_dice_coefficient: 0.8680 - val_iou_metric: 0.7702 - val_loss: 0.3038
# Epoch 47/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 233ms/step - accuracy: 0.9863 - dice_coefficient: 0.9469 - iou_metric: 0.8992 - loss: 0.0895 - val_accuracy: 0.9624 - val_dice_coefficient: 0.8712 - val_iou_metric: 0.7757 - val_loss: 0.3123
# Epoch 48/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.9866 - dice_coefficient: 0.9481 - iou_metric: 0.9015 - loss: 0.0873 - val_accuracy: 0.9632 - val_dice_coefficient: 0.8744 - val_iou_metric: 0.7804 - val_loss: 0.3096
# Epoch 49/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9875 - dice_coefficient: 0.9523 - iou_metric: 0.9090 - loss: 0.0807 - val_accuracy: 0.9621 - val_dice_coefficient: 0.8699 - val_iou_metric: 0.7732 - val_loss: 0.3378
# Epoch 50/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9884 - dice_coefficient: 0.9557 - iou_metric: 0.9153 - loss: 0.0750 - val_accuracy: 0.9627 - val_dice_coefficient: 0.8739 - val_iou_metric: 0.7799 - val_loss: 0.3466
# Epoch 51/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9894 - dice_coefficient: 0.9586 - iou_metric: 0.9206 - loss: 0.0695 - val_accuracy: 0.9634 - val_dice_coefficient: 0.8736 - val_iou_metric: 0.7792 - val_loss: 0.3423
# Epoch 52/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 233ms/step - accuracy: 0.9895 - dice_coefficient: 0.9591 - iou_metric: 0.9215 - loss: 0.0688 - val_accuracy: 0.9635 - val_dice_coefficient: 0.8752 - val_iou_metric: 0.7817 - val_loss: 0.3446
# Epoch 53/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 233ms/step - accuracy: 0.9896 - dice_coefficient: 0.9604 - iou_metric: 0.9239 - loss: 0.0671 - val_accuracy: 0.9635 - val_dice_coefficient: 0.8760 - val_iou_metric: 0.7829 - val_loss: 0.3468
# Epoch 54/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 40s 218ms/step - accuracy: 0.9898 - dice_coefficient: 0.9609 - iou_metric: 0.9249 - loss: 0.0661 - val_accuracy: 0.9629 - val_dice_coefficient: 0.8750 - val_iou_metric: 0.7815 - val_loss: 0.3377
# Epoch 55/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9901 - dice_coefficient: 0.9616 - iou_metric: 0.9261 - loss: 0.0643 - val_accuracy: 0.9634 - val_dice_coefficient: 0.8739 - val_iou_metric: 0.7796 - val_loss: 0.3667
# Epoch 56/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9910 - dice_coefficient: 0.9652 - iou_metric: 0.9328 - loss: 0.0582 - val_accuracy: 0.9632 - val_dice_coefficient: 0.8737 - val_iou_metric: 0.7792 - val_loss: 0.3899
# Epoch 57/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.9915 - dice_coefficient: 0.9669 - iou_metric: 0.9360 - loss: 0.0555 - val_accuracy: 0.9639 - val_dice_coefficient: 0.8763 - val_iou_metric: 0.7834 - val_loss: 0.3809
# Epoch 58/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.9917 - dice_coefficient: 0.9680 - iou_metric: 0.9380 - loss: 0.0538 - val_accuracy: 0.9643 - val_dice_coefficient: 0.8794 - val_iou_metric: 0.7884 - val_loss: 0.3749
# Epoch 59/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9918 - dice_coefficient: 0.9685 - iou_metric: 0.9390 - loss: 0.0531 - val_accuracy: 0.9636 - val_dice_coefficient: 0.8757 - val_iou_metric: 0.7826 - val_loss: 0.3740
# Epoch 60/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9921 - dice_coefficient: 0.9691 - iou_metric: 0.9401 - loss: 0.0514 - val_accuracy: 0.9640 - val_dice_coefficient: 0.8791 - val_iou_metric: 0.7881 - val_loss: 0.3819
# Epoch 61/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9918 - dice_coefficient: 0.9683 - iou_metric: 0.9385 - loss: 0.0531 - val_accuracy: 0.9641 - val_dice_coefficient: 0.8770 - val_iou_metric: 0.7846 - val_loss: 0.3848
# Epoch 62/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9920 - dice_coefficient: 0.9695 - iou_metric: 0.9409 - loss: 0.0513 - val_accuracy: 0.9643 - val_dice_coefficient: 0.8786 - val_iou_metric: 0.7872 - val_loss: 0.4130
# Epoch 63/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9924 - dice_coefficient: 0.9708 - iou_metric: 0.9432 - loss: 0.0494 - val_accuracy: 0.9636 - val_dice_coefficient: 0.8782 - val_iou_metric: 0.7869 - val_loss: 0.4191
# Epoch 64/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9921 - dice_coefficient: 0.9698 - iou_metric: 0.9414 - loss: 0.0513 - val_accuracy: 0.9646 - val_dice_coefficient: 0.8803 - val_iou_metric: 0.7899 - val_loss: 0.4017
# Epoch 65/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9929 - dice_coefficient: 0.9724 - iou_metric: 0.9462 - loss: 0.0462 - val_accuracy: 0.9642 - val_dice_coefficient: 0.8797 - val_iou_metric: 0.7889 - val_loss: 0.4022
# Epoch 66/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9929 - dice_coefficient: 0.9727 - iou_metric: 0.9469 - loss: 0.0459 - val_accuracy: 0.9642 - val_dice_coefficient: 0.8769 - val_iou_metric: 0.7845 - val_loss: 0.4318
# Epoch 67/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9930 - dice_coefficient: 0.9730 - iou_metric: 0.9475 - loss: 0.0454 - val_accuracy: 0.9644 - val_dice_coefficient: 0.8785 - val_iou_metric: 0.7869 - val_loss: 0.4276
# Epoch 68/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9932 - dice_coefficient: 0.9736 - iou_metric: 0.9486 - loss: 0.0442 - val_accuracy: 0.9641 - val_dice_coefficient: 0.8804 - val_iou_metric: 0.7903 - val_loss: 0.4044
# Epoch 69/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9929 - dice_coefficient: 0.9728 - iou_metric: 0.9471 - loss: 0.0456 - val_accuracy: 0.9643 - val_dice_coefficient: 0.8804 - val_iou_metric: 0.7902 - val_loss: 0.4371
# Epoch 70/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9934 - dice_coefficient: 0.9744 - iou_metric: 0.9502 - loss: 0.0431 - val_accuracy: 0.9643 - val_dice_coefficient: 0.8793 - val_iou_metric: 0.7885 - val_loss: 0.4356
# Epoch 71/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9936 - dice_coefficient: 0.9751 - iou_metric: 0.9514 - loss: 0.0418 - val_accuracy: 0.9646 - val_dice_coefficient: 0.8801 - val_iou_metric: 0.7895 - val_loss: 0.4625
# Epoch 72/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9940 - dice_coefficient: 0.9768 - iou_metric: 0.9547 - loss: 0.0391 - val_accuracy: 0.9646 - val_dice_coefficient: 0.8799 - val_iou_metric: 0.7894 - val_loss: 0.4616
# Epoch 73/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9939 - dice_coefficient: 0.9764 - iou_metric: 0.9540 - loss: 0.0398 - val_accuracy: 0.9646 - val_dice_coefficient: 0.8809 - val_iou_metric: 0.7910 - val_loss: 0.4286
# Epoch 74/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9935 - dice_coefficient: 0.9747 - iou_metric: 0.9506 - loss: 0.0424 - val_accuracy: 0.9651 - val_dice_coefficient: 0.8822 - val_iou_metric: 0.7931 - val_loss: 0.4444
# Epoch 75/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9939 - dice_coefficient: 0.9766 - iou_metric: 0.9543 - loss: 0.0393 - val_accuracy: 0.9648 - val_dice_coefficient: 0.8803 - val_iou_metric: 0.7898 - val_loss: 0.4560
# Epoch 76/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9939 - dice_coefficient: 0.9767 - iou_metric: 0.9544 - loss: 0.0394 - val_accuracy: 0.9648 - val_dice_coefficient: 0.8810 - val_iou_metric: 0.7912 - val_loss: 0.4448
# Epoch 77/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9940 - dice_coefficient: 0.9768 - iou_metric: 0.9547 - loss: 0.0389 - val_accuracy: 0.9651 - val_dice_coefficient: 0.8825 - val_iou_metric: 0.7935 - val_loss: 0.4631
# Epoch 78/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9940 - dice_coefficient: 0.9768 - iou_metric: 0.9547 - loss: 0.0391 - val_accuracy: 0.9651 - val_dice_coefficient: 0.8813 - val_iou_metric: 0.7917 - val_loss: 0.4511
# Epoch 79/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9941 - dice_coefficient: 0.9771 - iou_metric: 0.9552 - loss: 0.0382 - val_accuracy: 0.9650 - val_dice_coefficient: 0.8816 - val_iou_metric: 0.7921 - val_loss: 0.4539
# Epoch 80/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9941 - dice_coefficient: 0.9771 - iou_metric: 0.9553 - loss: 0.0384 - val_accuracy: 0.9647 - val_dice_coefficient: 0.8798 - val_iou_metric: 0.7892 - val_loss: 0.4490
# Epoch 81/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9939 - dice_coefficient: 0.9767 - iou_metric: 0.9545 - loss: 0.0392 - val_accuracy: 0.9650 - val_dice_coefficient: 0.8826 - val_iou_metric: 0.7938 - val_loss: 0.4555
# Epoch 82/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9942 - dice_coefficient: 0.9778 - iou_metric: 0.9567 - loss: 0.0372 - val_accuracy: 0.9651 - val_dice_coefficient: 0.8817 - val_iou_metric: 0.7925 - val_loss: 0.4721
# Epoch 83/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9943 - dice_coefficient: 0.9781 - iou_metric: 0.9573 - loss: 0.0368 - val_accuracy: 0.9649 - val_dice_coefficient: 0.8822 - val_iou_metric: 0.7932 - val_loss: 0.4917
# Epoch 84/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9942 - dice_coefficient: 0.9781 - iou_metric: 0.9571 - loss: 0.0374 - val_accuracy: 0.9647 - val_dice_coefficient: 0.8810 - val_iou_metric: 0.7913 - val_loss: 0.4743
# Epoch 85/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9945 - dice_coefficient: 0.9786 - iou_metric: 0.9582 - loss: 0.0357 - val_accuracy: 0.9652 - val_dice_coefficient: 0.8817 - val_iou_metric: 0.7925 - val_loss: 0.4743
# Epoch 86/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9947 - dice_coefficient: 0.9794 - iou_metric: 0.9597 - loss: 0.0344 - val_accuracy: 0.9654 - val_dice_coefficient: 0.8834 - val_iou_metric: 0.7950 - val_loss: 0.5000
# Epoch 87/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9948 - dice_coefficient: 0.9798 - iou_metric: 0.9604 - loss: 0.0339 - val_accuracy: 0.9647 - val_dice_coefficient: 0.8791 - val_iou_metric: 0.7882 - val_loss: 0.4669
# Epoch 88/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9945 - dice_coefficient: 0.9787 - iou_metric: 0.9584 - loss: 0.0356 - val_accuracy: 0.9652 - val_dice_coefficient: 0.8816 - val_iou_metric: 0.7923 - val_loss: 0.4798
# Epoch 89/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9946 - dice_coefficient: 0.9789 - iou_metric: 0.9587 - loss: 0.0352 - val_accuracy: 0.9652 - val_dice_coefficient: 0.8822 - val_iou_metric: 0.7931 - val_loss: 0.4958
# Epoch 90/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9946 - dice_coefficient: 0.9794 - iou_metric: 0.9597 - loss: 0.0346 - val_accuracy: 0.9650 - val_dice_coefficient: 0.8818 - val_iou_metric: 0.7923 - val_loss: 0.4947
# Epoch 91/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9946 - dice_coefficient: 0.9796 - iou_metric: 0.9601 - loss: 0.0345 - val_accuracy: 0.9651 - val_dice_coefficient: 0.8816 - val_iou_metric: 0.7920 - val_loss: 0.4814
# Epoch 92/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9948 - dice_coefficient: 0.9799 - iou_metric: 0.9606 - loss: 0.0338 - val_accuracy: 0.9648 - val_dice_coefficient: 0.8797 - val_iou_metric: 0.7890 - val_loss: 0.4909
# Epoch 93/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9946 - dice_coefficient: 0.9792 - iou_metric: 0.9593 - loss: 0.0348 - val_accuracy: 0.9651 - val_dice_coefficient: 0.8820 - val_iou_metric: 0.7928 - val_loss: 0.4920
# Epoch 94/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9948 - dice_coefficient: 0.9798 - iou_metric: 0.9604 - loss: 0.0339 - val_accuracy: 0.9650 - val_dice_coefficient: 0.8814 - val_iou_metric: 0.7919 - val_loss: 0.4875
# Epoch 95/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9948 - dice_coefficient: 0.9798 - iou_metric: 0.9605 - loss: 0.0338 - val_accuracy: 0.9654 - val_dice_coefficient: 0.8825 - val_iou_metric: 0.7935 - val_loss: 0.4997
# Epoch 96/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9950 - dice_coefficient: 0.9808 - iou_metric: 0.9623 - loss: 0.0322 - val_accuracy: 0.9652 - val_dice_coefficient: 0.8822 - val_iou_metric: 0.7932 - val_loss: 0.4889
#
# --- Fold 2 ---
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_32']
# Received: inputs=Tensor(shape=(None, 256, 256, 1))
#   warnings.warn(msg)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 274ms/step - accuracy: 0.8459 - dice_coefficient: 0.2002 - iou_metric: 0.1117 - loss: 1.3519 - val_accuracy: 0.8480 - val_dice_coefficient: 0.2083 - val_iou_metric: 0.1165 - val_loss: 1.2182
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.8388 - dice_coefficient: 0.2284 - iou_metric: 0.1299 - loss: 1.1978 - val_accuracy: 0.8480 - val_dice_coefficient: 0.1552 - val_iou_metric: 0.0842 - val_loss: 1.2875
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.8461 - dice_coefficient: 0.1908 - iou_metric: 0.1057 - loss: 1.2527 - val_accuracy: 0.8480 - val_dice_coefficient: 0.1954 - val_iou_metric: 0.1085 - val_loss: 1.2065
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.8492 - dice_coefficient: 0.3057 - iou_metric: 0.1838 - loss: 1.0452 - val_accuracy: 0.8613 - val_dice_coefficient: 0.4908 - val_iou_metric: 0.3267 - val_loss: 0.7606
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 221ms/step - accuracy: 0.9075 - dice_coefficient: 0.6386 - iou_metric: 0.4751 - loss: 0.5843 - val_accuracy: 0.9130 - val_dice_coefficient: 0.6885 - val_iou_metric: 0.5272 - val_loss: 0.5634
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9180 - dice_coefficient: 0.6978 - iou_metric: 0.5373 - loss: 0.5167 - val_accuracy: 0.9243 - val_dice_coefficient: 0.7375 - val_iou_metric: 0.5873 - val_loss: 0.4797
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9253 - dice_coefficient: 0.7233 - iou_metric: 0.5682 - loss: 0.4729 - val_accuracy: 0.9260 - val_dice_coefficient: 0.7443 - val_iou_metric: 0.5957 - val_loss: 0.4808
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9305 - dice_coefficient: 0.7387 - iou_metric: 0.5872 - loss: 0.4446 - val_accuracy: 0.9297 - val_dice_coefficient: 0.7395 - val_iou_metric: 0.5896 - val_loss: 0.4462
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9346 - dice_coefficient: 0.7533 - iou_metric: 0.6056 - loss: 0.4162 - val_accuracy: 0.9353 - val_dice_coefficient: 0.7225 - val_iou_metric: 0.5682 - val_loss: 0.4601
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9341 - dice_coefficient: 0.7481 - iou_metric: 0.5989 - loss: 0.4219 - val_accuracy: 0.9336 - val_dice_coefficient: 0.7438 - val_iou_metric: 0.5954 - val_loss: 0.4204
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9392 - dice_coefficient: 0.7695 - iou_metric: 0.6270 - loss: 0.3914 - val_accuracy: 0.9425 - val_dice_coefficient: 0.7817 - val_iou_metric: 0.6449 - val_loss: 0.3899
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9452 - dice_coefficient: 0.7935 - iou_metric: 0.6587 - loss: 0.3532 - val_accuracy: 0.9443 - val_dice_coefficient: 0.7611 - val_iou_metric: 0.6171 - val_loss: 0.4065
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9487 - dice_coefficient: 0.8022 - iou_metric: 0.6710 - loss: 0.3356 - val_accuracy: 0.9461 - val_dice_coefficient: 0.7745 - val_iou_metric: 0.6351 - val_loss: 0.3712
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 221ms/step - accuracy: 0.9528 - dice_coefficient: 0.8174 - iou_metric: 0.6929 - loss: 0.3090 - val_accuracy: 0.9523 - val_dice_coefficient: 0.8054 - val_iou_metric: 0.6775 - val_loss: 0.3213
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 221ms/step - accuracy: 0.9563 - dice_coefficient: 0.8331 - iou_metric: 0.7155 - loss: 0.2839 - val_accuracy: 0.9501 - val_dice_coefficient: 0.8086 - val_iou_metric: 0.6824 - val_loss: 0.3212
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9602 - dice_coefficient: 0.8485 - iou_metric: 0.7381 - loss: 0.2593 - val_accuracy: 0.9580 - val_dice_coefficient: 0.8322 - val_iou_metric: 0.7159 - val_loss: 0.2801
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9627 - dice_coefficient: 0.8561 - iou_metric: 0.7498 - loss: 0.2461 - val_accuracy: 0.9550 - val_dice_coefficient: 0.8250 - val_iou_metric: 0.7058 - val_loss: 0.2913
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9624 - dice_coefficient: 0.8542 - iou_metric: 0.7466 - loss: 0.2481 - val_accuracy: 0.9596 - val_dice_coefficient: 0.8300 - val_iou_metric: 0.7125 - val_loss: 0.2806
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9646 - dice_coefficient: 0.8651 - iou_metric: 0.7634 - loss: 0.2328 - val_accuracy: 0.9603 - val_dice_coefficient: 0.8168 - val_iou_metric: 0.6932 - val_loss: 0.2861
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9654 - dice_coefficient: 0.8641 - iou_metric: 0.7617 - loss: 0.2317 - val_accuracy: 0.9572 - val_dice_coefficient: 0.8112 - val_iou_metric: 0.6858 - val_loss: 0.2966
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9660 - dice_coefficient: 0.8644 - iou_metric: 0.7623 - loss: 0.2271 - val_accuracy: 0.9592 - val_dice_coefficient: 0.8273 - val_iou_metric: 0.7089 - val_loss: 0.2787
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9666 - dice_coefficient: 0.8696 - iou_metric: 0.7705 - loss: 0.2199 - val_accuracy: 0.9621 - val_dice_coefficient: 0.8266 - val_iou_metric: 0.7079 - val_loss: 0.2717
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9678 - dice_coefficient: 0.8731 - iou_metric: 0.7757 - loss: 0.2133 - val_accuracy: 0.9621 - val_dice_coefficient: 0.8272 - val_iou_metric: 0.7087 - val_loss: 0.2716
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9695 - dice_coefficient: 0.8830 - iou_metric: 0.7914 - loss: 0.2000 - val_accuracy: 0.9599 - val_dice_coefficient: 0.8182 - val_iou_metric: 0.6958 - val_loss: 0.2844
# Epoch 25/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9691 - dice_coefficient: 0.8762 - iou_metric: 0.7810 - loss: 0.2067 - val_accuracy: 0.9610 - val_dice_coefficient: 0.8202 - val_iou_metric: 0.6985 - val_loss: 0.2864
# Epoch 26/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9699 - dice_coefficient: 0.8798 - iou_metric: 0.7868 - loss: 0.2020 - val_accuracy: 0.9562 - val_dice_coefficient: 0.8029 - val_iou_metric: 0.6741 - val_loss: 0.3096
#
# --- Fold 3 ---
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_64']
# Received: inputs=Tensor(shape=(None, 256, 256, 1))
#   warnings.warn(msg)
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 41s 277ms/step - accuracy: 0.7580 - dice_coefficient: 0.2091 - iou_metric: 0.1174 - loss: 1.3493 - val_accuracy: 0.8573 - val_dice_coefficient: 0.1933 - val_iou_metric: 0.1072 - val_loss: 1.2689
# Epoch 2/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.8407 - dice_coefficient: 0.2706 - iou_metric: 0.1584 - loss: 1.1341 - val_accuracy: 0.8709 - val_dice_coefficient: 0.4221 - val_iou_metric: 0.2688 - val_loss: 0.9510
# Epoch 3/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.8777 - dice_coefficient: 0.5634 - iou_metric: 0.3979 - loss: 0.7388 - val_accuracy: 0.9238 - val_dice_coefficient: 0.6804 - val_iou_metric: 0.5194 - val_loss: 0.5089
# Epoch 4/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9177 - dice_coefficient: 0.7036 - iou_metric: 0.5439 - loss: 0.5088 - val_accuracy: 0.9298 - val_dice_coefficient: 0.7150 - val_iou_metric: 0.5603 - val_loss: 0.4613
# Epoch 5/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9266 - dice_coefficient: 0.7294 - iou_metric: 0.5751 - loss: 0.4603 - val_accuracy: 0.9321 - val_dice_coefficient: 0.7080 - val_iou_metric: 0.5518 - val_loss: 0.4666
# Epoch 6/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9295 - dice_coefficient: 0.7425 - iou_metric: 0.5923 - loss: 0.4407 - val_accuracy: 0.9302 - val_dice_coefficient: 0.7223 - val_iou_metric: 0.5693 - val_loss: 0.4688
# Epoch 7/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9318 - dice_coefficient: 0.7524 - iou_metric: 0.6046 - loss: 0.4284 - val_accuracy: 0.9373 - val_dice_coefficient: 0.7385 - val_iou_metric: 0.5897 - val_loss: 0.4211
# Epoch 8/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9343 - dice_coefficient: 0.7605 - iou_metric: 0.6146 - loss: 0.4101 - val_accuracy: 0.9360 - val_dice_coefficient: 0.7219 - val_iou_metric: 0.5690 - val_loss: 0.4374
# Epoch 9/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9340 - dice_coefficient: 0.7571 - iou_metric: 0.6105 - loss: 0.4152 - val_accuracy: 0.9425 - val_dice_coefficient: 0.7441 - val_iou_metric: 0.5967 - val_loss: 0.3979
# Epoch 10/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9399 - dice_coefficient: 0.7716 - iou_metric: 0.6300 - loss: 0.3849 - val_accuracy: 0.9415 - val_dice_coefficient: 0.7725 - val_iou_metric: 0.6342 - val_loss: 0.3863
# Epoch 11/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9416 - dice_coefficient: 0.7854 - iou_metric: 0.6480 - loss: 0.3687 - val_accuracy: 0.9381 - val_dice_coefficient: 0.7658 - val_iou_metric: 0.6252 - val_loss: 0.3956
# Epoch 12/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9426 - dice_coefficient: 0.7903 - iou_metric: 0.6544 - loss: 0.3622 - val_accuracy: 0.9438 - val_dice_coefficient: 0.7730 - val_iou_metric: 0.6350 - val_loss: 0.3733
# Epoch 13/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9460 - dice_coefficient: 0.7986 - iou_metric: 0.6660 - loss: 0.3425 - val_accuracy: 0.9433 - val_dice_coefficient: 0.7853 - val_iou_metric: 0.6515 - val_loss: 0.3884
# Epoch 14/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9483 - dice_coefficient: 0.8085 - iou_metric: 0.6799 - loss: 0.3313 - val_accuracy: 0.9457 - val_dice_coefficient: 0.7923 - val_iou_metric: 0.6617 - val_loss: 0.3665
# Epoch 15/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9511 - dice_coefficient: 0.8201 - iou_metric: 0.6964 - loss: 0.3148 - val_accuracy: 0.9510 - val_dice_coefficient: 0.7911 - val_iou_metric: 0.6598 - val_loss: 0.3357
# Epoch 16/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9536 - dice_coefficient: 0.8271 - iou_metric: 0.7061 - loss: 0.2930 - val_accuracy: 0.9474 - val_dice_coefficient: 0.7914 - val_iou_metric: 0.6601 - val_loss: 0.3478
# Epoch 17/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9547 - dice_coefficient: 0.8325 - iou_metric: 0.7142 - loss: 0.2880 - val_accuracy: 0.9566 - val_dice_coefficient: 0.7910 - val_iou_metric: 0.6594 - val_loss: 0.3213
# Epoch 18/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9590 - dice_coefficient: 0.8433 - iou_metric: 0.7300 - loss: 0.2660 - val_accuracy: 0.9599 - val_dice_coefficient: 0.8211 - val_iou_metric: 0.7019 - val_loss: 0.2836
# Epoch 19/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 221ms/step - accuracy: 0.9615 - dice_coefficient: 0.8562 - iou_metric: 0.7497 - loss: 0.2460 - val_accuracy: 0.9609 - val_dice_coefficient: 0.8290 - val_iou_metric: 0.7135 - val_loss: 0.2782
# Epoch 20/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 221ms/step - accuracy: 0.9619 - dice_coefficient: 0.8578 - iou_metric: 0.7520 - loss: 0.2429 - val_accuracy: 0.9608 - val_dice_coefficient: 0.8358 - val_iou_metric: 0.7234 - val_loss: 0.2712
# Epoch 21/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9632 - dice_coefficient: 0.8635 - iou_metric: 0.7608 - loss: 0.2365 - val_accuracy: 0.9608 - val_dice_coefficient: 0.8291 - val_iou_metric: 0.7136 - val_loss: 0.2751
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9648 - dice_coefficient: 0.8699 - iou_metric: 0.7705 - loss: 0.2249 - val_accuracy: 0.9596 - val_dice_coefficient: 0.8227 - val_iou_metric: 0.7038 - val_loss: 0.2852
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9635 - dice_coefficient: 0.8625 - iou_metric: 0.7594 - loss: 0.2336 - val_accuracy: 0.9585 - val_dice_coefficient: 0.8285 - val_iou_metric: 0.7125 - val_loss: 0.2810
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9645 - dice_coefficient: 0.8679 - iou_metric: 0.7676 - loss: 0.2275 - val_accuracy: 0.9623 - val_dice_coefficient: 0.8303 - val_iou_metric: 0.7153 - val_loss: 0.2727
# Epoch 25/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9656 - dice_coefficient: 0.8730 - iou_metric: 0.7757 - loss: 0.2211 - val_accuracy: 0.9627 - val_dice_coefficient: 0.8407 - val_iou_metric: 0.7308 - val_loss: 0.2673
# Epoch 26/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9661 - dice_coefficient: 0.8729 - iou_metric: 0.7758 - loss: 0.2203 - val_accuracy: 0.9627 - val_dice_coefficient: 0.8399 - val_iou_metric: 0.7291 - val_loss: 0.2616
# Epoch 27/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9673 - dice_coefficient: 0.8791 - iou_metric: 0.7852 - loss: 0.2102 - val_accuracy: 0.9629 - val_dice_coefficient: 0.8371 - val_iou_metric: 0.7255 - val_loss: 0.2654
# Epoch 28/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9681 - dice_coefficient: 0.8787 - iou_metric: 0.7849 - loss: 0.2070 - val_accuracy: 0.9620 - val_dice_coefficient: 0.8237 - val_iou_metric: 0.7055 - val_loss: 0.2742
# Epoch 29/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9687 - dice_coefficient: 0.8789 - iou_metric: 0.7848 - loss: 0.2046 - val_accuracy: 0.9561 - val_dice_coefficient: 0.8208 - val_iou_metric: 0.7015 - val_loss: 0.2934
# Epoch 30/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9681 - dice_coefficient: 0.8802 - iou_metric: 0.7871 - loss: 0.2063 - val_accuracy: 0.9619 - val_dice_coefficient: 0.8252 - val_iou_metric: 0.7072 - val_loss: 0.2739
# Epoch 31/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 221ms/step - accuracy: 0.9683 - dice_coefficient: 0.8805 - iou_metric: 0.7874 - loss: 0.2045 - val_accuracy: 0.9641 - val_dice_coefficient: 0.8413 - val_iou_metric: 0.7315 - val_loss: 0.2600
# Epoch 32/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9696 - dice_coefficient: 0.8872 - iou_metric: 0.7980 - loss: 0.1947 - val_accuracy: 0.9624 - val_dice_coefficient: 0.8355 - val_iou_metric: 0.7223 - val_loss: 0.2703
# Epoch 33/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9702 - dice_coefficient: 0.8885 - iou_metric: 0.8001 - loss: 0.1932 - val_accuracy: 0.9612 - val_dice_coefficient: 0.8244 - val_iou_metric: 0.7061 - val_loss: 0.2754
# Epoch 34/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9707 - dice_coefficient: 0.8903 - iou_metric: 0.8029 - loss: 0.1884 - val_accuracy: 0.9620 - val_dice_coefficient: 0.8303 - val_iou_metric: 0.7148 - val_loss: 0.2706
# Epoch 35/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9712 - dice_coefficient: 0.8911 - iou_metric: 0.8044 - loss: 0.1871 - val_accuracy: 0.9621 - val_dice_coefficient: 0.8376 - val_iou_metric: 0.7259 - val_loss: 0.2760
# Epoch 36/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9713 - dice_coefficient: 0.8908 - iou_metric: 0.8041 - loss: 0.1870 - val_accuracy: 0.9620 - val_dice_coefficient: 0.8297 - val_iou_metric: 0.7133 - val_loss: 0.2715
# Epoch 37/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9722 - dice_coefficient: 0.8940 - iou_metric: 0.8094 - loss: 0.1804 - val_accuracy: 0.9623 - val_dice_coefficient: 0.8340 - val_iou_metric: 0.7207 - val_loss: 0.2733
# Epoch 38/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9733 - dice_coefficient: 0.8995 - iou_metric: 0.8181 - loss: 0.1743 - val_accuracy: 0.9617 - val_dice_coefficient: 0.8435 - val_iou_metric: 0.7341 - val_loss: 0.2634
# Epoch 39/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9748 - dice_coefficient: 0.9046 - iou_metric: 0.8266 - loss: 0.1641 - val_accuracy: 0.9619 - val_dice_coefficient: 0.8403 - val_iou_metric: 0.7293 - val_loss: 0.2681
# Epoch 40/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9741 - dice_coefficient: 0.9037 - iou_metric: 0.8249 - loss: 0.1665 - val_accuracy: 0.9659 - val_dice_coefficient: 0.8576 - val_iou_metric: 0.7556 - val_loss: 0.2429
# Epoch 41/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9751 - dice_coefficient: 0.9068 - iou_metric: 0.8303 - loss: 0.1603 - val_accuracy: 0.9639 - val_dice_coefficient: 0.8460 - val_iou_metric: 0.7376 - val_loss: 0.2573
# Epoch 42/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9760 - dice_coefficient: 0.9078 - iou_metric: 0.8319 - loss: 0.1561 - val_accuracy: 0.9605 - val_dice_coefficient: 0.8412 - val_iou_metric: 0.7305 - val_loss: 0.2749
# Epoch 43/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9774 - dice_coefficient: 0.9146 - iou_metric: 0.8431 - loss: 0.1463 - val_accuracy: 0.9651 - val_dice_coefficient: 0.8565 - val_iou_metric: 0.7540 - val_loss: 0.2496
# Epoch 44/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9786 - dice_coefficient: 0.9192 - iou_metric: 0.8509 - loss: 0.1382 - val_accuracy: 0.9626 - val_dice_coefficient: 0.8456 - val_iou_metric: 0.7366 - val_loss: 0.2729
# Epoch 45/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9797 - dice_coefficient: 0.9222 - iou_metric: 0.8561 - loss: 0.1319 - val_accuracy: 0.9647 - val_dice_coefficient: 0.8631 - val_iou_metric: 0.7642 - val_loss: 0.2541
# Epoch 46/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 221ms/step - accuracy: 0.9802 - dice_coefficient: 0.9253 - iou_metric: 0.8613 - loss: 0.1278 - val_accuracy: 0.9669 - val_dice_coefficient: 0.8695 - val_iou_metric: 0.7737 - val_loss: 0.2456
# Epoch 47/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9819 - dice_coefficient: 0.9319 - iou_metric: 0.8727 - loss: 0.1166 - val_accuracy: 0.9670 - val_dice_coefficient: 0.8698 - val_iou_metric: 0.7749 - val_loss: 0.2538
# Epoch 48/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9825 - dice_coefficient: 0.9352 - iou_metric: 0.8784 - loss: 0.1120 - val_accuracy: 0.9660 - val_dice_coefficient: 0.8656 - val_iou_metric: 0.7677 - val_loss: 0.2673
# Epoch 49/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9826 - dice_coefficient: 0.9350 - iou_metric: 0.8782 - loss: 0.1116 - val_accuracy: 0.9656 - val_dice_coefficient: 0.8658 - val_iou_metric: 0.7680 - val_loss: 0.2741
# Epoch 50/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9839 - dice_coefficient: 0.9388 - iou_metric: 0.8848 - loss: 0.1044 - val_accuracy: 0.9647 - val_dice_coefficient: 0.8676 - val_iou_metric: 0.7707 - val_loss: 0.2778
# Epoch 51/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9850 - dice_coefficient: 0.9443 - iou_metric: 0.8947 - loss: 0.0959 - val_accuracy: 0.9661 - val_dice_coefficient: 0.8739 - val_iou_metric: 0.7809 - val_loss: 0.2684
# Epoch 52/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9861 - dice_coefficient: 0.9476 - iou_metric: 0.9006 - loss: 0.0894 - val_accuracy: 0.9667 - val_dice_coefficient: 0.8773 - val_iou_metric: 0.7864 - val_loss: 0.2722
# Epoch 53/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9867 - dice_coefficient: 0.9509 - iou_metric: 0.9064 - loss: 0.0844 - val_accuracy: 0.9676 - val_dice_coefficient: 0.8758 - val_iou_metric: 0.7839 - val_loss: 0.2685
# Epoch 54/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9871 - dice_coefficient: 0.9519 - iou_metric: 0.9083 - loss: 0.0820 - val_accuracy: 0.9672 - val_dice_coefficient: 0.8752 - val_iou_metric: 0.7829 - val_loss: 0.2874
# Epoch 55/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9884 - dice_coefficient: 0.9566 - iou_metric: 0.9169 - loss: 0.0745 - val_accuracy: 0.9662 - val_dice_coefficient: 0.8730 - val_iou_metric: 0.7795 - val_loss: 0.2935
# Epoch 56/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 221ms/step - accuracy: 0.9887 - dice_coefficient: 0.9573 - iou_metric: 0.9181 - loss: 0.0723 - val_accuracy: 0.9677 - val_dice_coefficient: 0.8780 - val_iou_metric: 0.7878 - val_loss: 0.2845
# Epoch 57/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9887 - dice_coefficient: 0.9576 - iou_metric: 0.9188 - loss: 0.0722 - val_accuracy: 0.9667 - val_dice_coefficient: 0.8759 - val_iou_metric: 0.7844 - val_loss: 0.2938
# Epoch 58/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9892 - dice_coefficient: 0.9588 - iou_metric: 0.9210 - loss: 0.0693 - val_accuracy: 0.9671 - val_dice_coefficient: 0.8780 - val_iou_metric: 0.7876 - val_loss: 0.3053
# Epoch 59/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.9898 - dice_coefficient: 0.9618 - iou_metric: 0.9266 - loss: 0.0652 - val_accuracy: 0.9687 - val_dice_coefficient: 0.8838 - val_iou_metric: 0.7969 - val_loss: 0.3011
# Epoch 60/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9909 - dice_coefficient: 0.9656 - iou_metric: 0.9335 - loss: 0.0585 - val_accuracy: 0.9681 - val_dice_coefficient: 0.8835 - val_iou_metric: 0.7964 - val_loss: 0.2989
# Epoch 61/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9902 - dice_coefficient: 0.9634 - iou_metric: 0.9294 - loss: 0.0626 - val_accuracy: 0.9676 - val_dice_coefficient: 0.8800 - val_iou_metric: 0.7910 - val_loss: 0.3035
# Epoch 62/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9906 - dice_coefficient: 0.9648 - iou_metric: 0.9320 - loss: 0.0599 - val_accuracy: 0.9686 - val_dice_coefficient: 0.8829 - val_iou_metric: 0.7954 - val_loss: 0.3050
# Epoch 63/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 232ms/step - accuracy: 0.9911 - dice_coefficient: 0.9668 - iou_metric: 0.9357 - loss: 0.0566 - val_accuracy: 0.9685 - val_dice_coefficient: 0.8839 - val_iou_metric: 0.7972 - val_loss: 0.3040
# Epoch 64/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9917 - dice_coefficient: 0.9691 - iou_metric: 0.9400 - loss: 0.0523 - val_accuracy: 0.9685 - val_dice_coefficient: 0.8832 - val_iou_metric: 0.7962 - val_loss: 0.3182
# Epoch 65/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9916 - dice_coefficient: 0.9683 - iou_metric: 0.9386 - loss: 0.0535 - val_accuracy: 0.9674 - val_dice_coefficient: 0.8816 - val_iou_metric: 0.7934 - val_loss: 0.3202
# Epoch 66/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 23s 231ms/step - accuracy: 0.9916 - dice_coefficient: 0.9681 - iou_metric: 0.9383 - loss: 0.0536 - val_accuracy: 0.9689 - val_dice_coefficient: 0.8859 - val_iou_metric: 0.8007 - val_loss: 0.3175
# Epoch 67/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9921 - dice_coefficient: 0.9699 - iou_metric: 0.9415 - loss: 0.0508 - val_accuracy: 0.9681 - val_dice_coefficient: 0.8826 - val_iou_metric: 0.7951 - val_loss: 0.3401
# Epoch 68/100
# ...
# Epoch 22/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9644 - dice_coefficient: 0.8621 - iou_metric: 0.7586 - loss: 0.2347 - val_accuracy: 0.9579 - val_dice_coefficient: 0.8238 - val_iou_metric: 0.7030 - val_loss: 0.2857
# Epoch 23/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9650 - dice_coefficient: 0.8677 - iou_metric: 0.7672 - loss: 0.2269 - val_accuracy: 0.9541 - val_dice_coefficient: 0.8178 - val_iou_metric: 0.6950 - val_loss: 0.3005
# Epoch 24/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9645 - dice_coefficient: 0.8655 - iou_metric: 0.7639 - loss: 0.2302 - val_accuracy: 0.9573 - val_dice_coefficient: 0.8161 - val_iou_metric: 0.6922 - val_loss: 0.2993
# Epoch 25/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9662 - dice_coefficient: 0.8731 - iou_metric: 0.7756 - loss: 0.2181 - val_accuracy: 0.9596 - val_dice_coefficient: 0.8342 - val_iou_metric: 0.7184 - val_loss: 0.2779
# Epoch 26/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9663 - dice_coefficient: 0.8701 - iou_metric: 0.7713 - loss: 0.2205 - val_accuracy: 0.9591 - val_dice_coefficient: 0.8297 - val_iou_metric: 0.7116 - val_loss: 0.2795
# Epoch 27/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9681 - dice_coefficient: 0.8788 - iou_metric: 0.7848 - loss: 0.2076 - val_accuracy: 0.9593 - val_dice_coefficient: 0.8222 - val_iou_metric: 0.7006 - val_loss: 0.2869
# Epoch 28/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9676 - dice_coefficient: 0.8751 - iou_metric: 0.7789 - loss: 0.2117 - val_accuracy: 0.9605 - val_dice_coefficient: 0.8350 - val_iou_metric: 0.7193 - val_loss: 0.2694
# Epoch 29/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9696 - dice_coefficient: 0.8848 - iou_metric: 0.7942 - loss: 0.1978 - val_accuracy: 0.9583 - val_dice_coefficient: 0.8196 - val_iou_metric: 0.6967 - val_loss: 0.2938
# Epoch 30/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9699 - dice_coefficient: 0.8848 - iou_metric: 0.7944 - loss: 0.1966 - val_accuracy: 0.9609 - val_dice_coefficient: 0.8454 - val_iou_metric: 0.7346 - val_loss: 0.2786
# Epoch 31/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9712 - dice_coefficient: 0.8926 - iou_metric: 0.8067 - loss: 0.1861 - val_accuracy: 0.9605 - val_dice_coefficient: 0.8443 - val_iou_metric: 0.7332 - val_loss: 0.2792
# Epoch 32/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9700 - dice_coefficient: 0.8876 - iou_metric: 0.7988 - loss: 0.1938 - val_accuracy: 0.9587 - val_dice_coefficient: 0.8207 - val_iou_metric: 0.6984 - val_loss: 0.2887
# Epoch 33/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9714 - dice_coefficient: 0.8905 - iou_metric: 0.8033 - loss: 0.1869 - val_accuracy: 0.9595 - val_dice_coefficient: 0.8487 - val_iou_metric: 0.7398 - val_loss: 0.2696
# Epoch 34/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9720 - dice_coefficient: 0.8938 - iou_metric: 0.8088 - loss: 0.1828 - val_accuracy: 0.9579 - val_dice_coefficient: 0.8368 - val_iou_metric: 0.7213 - val_loss: 0.2975
# Epoch 35/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9719 - dice_coefficient: 0.8938 - iou_metric: 0.8088 - loss: 0.1841 - val_accuracy: 0.9601 - val_dice_coefficient: 0.8349 - val_iou_metric: 0.7191 - val_loss: 0.2713
# Epoch 36/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9738 - dice_coefficient: 0.8984 - iou_metric: 0.8162 - loss: 0.1720 - val_accuracy: 0.9582 - val_dice_coefficient: 0.8283 - val_iou_metric: 0.7092 - val_loss: 0.2935
# Epoch 37/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9748 - dice_coefficient: 0.9036 - iou_metric: 0.8247 - loss: 0.1637 - val_accuracy: 0.9572 - val_dice_coefficient: 0.8431 - val_iou_metric: 0.7309 - val_loss: 0.2898
# Epoch 38/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9742 - dice_coefficient: 0.9040 - iou_metric: 0.8253 - loss: 0.1667 - val_accuracy: 0.9606 - val_dice_coefficient: 0.8457 - val_iou_metric: 0.7351 - val_loss: 0.2724
# Epoch 39/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9758 - dice_coefficient: 0.9077 - iou_metric: 0.8314 - loss: 0.1569 - val_accuracy: 0.9614 - val_dice_coefficient: 0.8538 - val_iou_metric: 0.7472 - val_loss: 0.2683
# Epoch 40/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9775 - dice_coefficient: 0.9137 - iou_metric: 0.8416 - loss: 0.1470 - val_accuracy: 0.9614 - val_dice_coefficient: 0.8551 - val_iou_metric: 0.7493 - val_loss: 0.2688
# Epoch 41/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9781 - dice_coefficient: 0.9179 - iou_metric: 0.8485 - loss: 0.1414 - val_accuracy: 0.9620 - val_dice_coefficient: 0.8611 - val_iou_metric: 0.7584 - val_loss: 0.2651
# Epoch 42/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9803 - dice_coefficient: 0.9243 - iou_metric: 0.8597 - loss: 0.1282 - val_accuracy: 0.9620 - val_dice_coefficient: 0.8574 - val_iou_metric: 0.7526 - val_loss: 0.2717
# Epoch 43/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9809 - dice_coefficient: 0.9276 - iou_metric: 0.8653 - loss: 0.1235 - val_accuracy: 0.9616 - val_dice_coefficient: 0.8578 - val_iou_metric: 0.7531 - val_loss: 0.2839
# Epoch 44/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9824 - dice_coefficient: 0.9327 - iou_metric: 0.8742 - loss: 0.1144 - val_accuracy: 0.9619 - val_dice_coefficient: 0.8621 - val_iou_metric: 0.7602 - val_loss: 0.2816
# Epoch 45/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9828 - dice_coefficient: 0.9344 - iou_metric: 0.8771 - loss: 0.1112 - val_accuracy: 0.9631 - val_dice_coefficient: 0.8669 - val_iou_metric: 0.7675 - val_loss: 0.2881
# Epoch 46/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9840 - dice_coefficient: 0.9393 - iou_metric: 0.8858 - loss: 0.1040 - val_accuracy: 0.9627 - val_dice_coefficient: 0.8650 - val_iou_metric: 0.7645 - val_loss: 0.2933
# Epoch 47/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9851 - dice_coefficient: 0.9428 - iou_metric: 0.8921 - loss: 0.0972 - val_accuracy: 0.9630 - val_dice_coefficient: 0.8677 - val_iou_metric: 0.7684 - val_loss: 0.3045
# Epoch 48/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9851 - dice_coefficient: 0.9434 - iou_metric: 0.8931 - loss: 0.0966 - val_accuracy: 0.9632 - val_dice_coefficient: 0.8707 - val_iou_metric: 0.7735 - val_loss: 0.2986
# Epoch 49/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9875 - dice_coefficient: 0.9523 - iou_metric: 0.9091 - loss: 0.0810 - val_accuracy: 0.9640 - val_dice_coefficient: 0.8734 - val_iou_metric: 0.7776 - val_loss: 0.3036
# Epoch 50/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9885 - dice_coefficient: 0.9562 - iou_metric: 0.9162 - loss: 0.0745 - val_accuracy: 0.9632 - val_dice_coefficient: 0.8708 - val_iou_metric: 0.7737 - val_loss: 0.3021
# Epoch 51/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9878 - dice_coefficient: 0.9533 - iou_metric: 0.9108 - loss: 0.0790 - val_accuracy: 0.9637 - val_dice_coefficient: 0.8730 - val_iou_metric: 0.7770 - val_loss: 0.3131
# Epoch 52/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9887 - dice_coefficient: 0.9570 - iou_metric: 0.9176 - loss: 0.0729 - val_accuracy: 0.9642 - val_dice_coefficient: 0.8743 - val_iou_metric: 0.7792 - val_loss: 0.3162
# Epoch 53/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9893 - dice_coefficient: 0.9586 - iou_metric: 0.9206 - loss: 0.0696 - val_accuracy: 0.9634 - val_dice_coefficient: 0.8736 - val_iou_metric: 0.7778 - val_loss: 0.3317
# Epoch 54/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9896 - dice_coefficient: 0.9609 - iou_metric: 0.9247 - loss: 0.0665 - val_accuracy: 0.9637 - val_dice_coefficient: 0.8751 - val_iou_metric: 0.7806 - val_loss: 0.3316
# Epoch 55/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9902 - dice_coefficient: 0.9625 - iou_metric: 0.9279 - loss: 0.0631 - val_accuracy: 0.9638 - val_dice_coefficient: 0.8741 - val_iou_metric: 0.7790 - val_loss: 0.3392
# Epoch 56/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9907 - dice_coefficient: 0.9646 - iou_metric: 0.9317 - loss: 0.0598 - val_accuracy: 0.9640 - val_dice_coefficient: 0.8763 - val_iou_metric: 0.7821 - val_loss: 0.3448
# Epoch 57/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9914 - dice_coefficient: 0.9670 - iou_metric: 0.9362 - loss: 0.0558 - val_accuracy: 0.9641 - val_dice_coefficient: 0.8751 - val_iou_metric: 0.7805 - val_loss: 0.3467
# Epoch 58/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9914 - dice_coefficient: 0.9669 - iou_metric: 0.9359 - loss: 0.0558 - val_accuracy: 0.9646 - val_dice_coefficient: 0.8767 - val_iou_metric: 0.7829 - val_loss: 0.3464
# Epoch 59/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9918 - dice_coefficient: 0.9688 - iou_metric: 0.9394 - loss: 0.0526 - val_accuracy: 0.9643 - val_dice_coefficient: 0.8760 - val_iou_metric: 0.7819 - val_loss: 0.3566
# Epoch 60/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9916 - dice_coefficient: 0.9685 - iou_metric: 0.9389 - loss: 0.0536 - val_accuracy: 0.9645 - val_dice_coefficient: 0.8779 - val_iou_metric: 0.7850 - val_loss: 0.3712
# Epoch 61/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9922 - dice_coefficient: 0.9704 - iou_metric: 0.9425 - loss: 0.0500 - val_accuracy: 0.9646 - val_dice_coefficient: 0.8794 - val_iou_metric: 0.7873 - val_loss: 0.3575
# Epoch 62/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9917 - dice_coefficient: 0.9685 - iou_metric: 0.9390 - loss: 0.0535 - val_accuracy: 0.9648 - val_dice_coefficient: 0.8773 - val_iou_metric: 0.7840 - val_loss: 0.3795
# Epoch 63/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9922 - dice_coefficient: 0.9700 - iou_metric: 0.9419 - loss: 0.0507 - val_accuracy: 0.9645 - val_dice_coefficient: 0.8772 - val_iou_metric: 0.7838 - val_loss: 0.3864
# Epoch 64/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9925 - dice_coefficient: 0.9718 - iou_metric: 0.9451 - loss: 0.0479 - val_accuracy: 0.9645 - val_dice_coefficient: 0.8786 - val_iou_metric: 0.7861 - val_loss: 0.3769
# Epoch 65/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 220ms/step - accuracy: 0.9922 - dice_coefficient: 0.9707 - iou_metric: 0.9432 - loss: 0.0499 - val_accuracy: 0.9647 - val_dice_coefficient: 0.8794 - val_iou_metric: 0.7874 - val_loss: 0.3563
# Epoch 66/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9925 - dice_coefficient: 0.9709 - iou_metric: 0.9435 - loss: 0.0487 - val_accuracy: 0.9648 - val_dice_coefficient: 0.8784 - val_iou_metric: 0.7858 - val_loss: 0.3790
# Epoch 67/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9930 - dice_coefficient: 0.9728 - iou_metric: 0.9471 - loss: 0.0456 - val_accuracy: 0.9651 - val_dice_coefficient: 0.8789 - val_iou_metric: 0.7864 - val_loss: 0.3873
# Epoch 68/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9931 - dice_coefficient: 0.9743 - iou_metric: 0.9499 - loss: 0.0437 - val_accuracy: 0.9643 - val_dice_coefficient: 0.8763 - val_iou_metric: 0.7825 - val_loss: 0.3969
# Epoch 69/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9933 - dice_coefficient: 0.9742 - iou_metric: 0.9497 - loss: 0.0433 - val_accuracy: 0.9650 - val_dice_coefficient: 0.8800 - val_iou_metric: 0.7883 - val_loss: 0.3994
# Epoch 70/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9934 - dice_coefficient: 0.9745 - iou_metric: 0.9503 - loss: 0.0433 - val_accuracy: 0.9647 - val_dice_coefficient: 0.8796 - val_iou_metric: 0.7877 - val_loss: 0.3993
# Epoch 71/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9932 - dice_coefficient: 0.9743 - iou_metric: 0.9499 - loss: 0.0436 - val_accuracy: 0.9653 - val_dice_coefficient: 0.8813 - val_iou_metric: 0.7903 - val_loss: 0.4024
# Epoch 72/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9937 - dice_coefficient: 0.9756 - iou_metric: 0.9525 - loss: 0.0410 - val_accuracy: 0.9650 - val_dice_coefficient: 0.8799 - val_iou_metric: 0.7883 - val_loss: 0.4071
# Epoch 73/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9937 - dice_coefficient: 0.9758 - iou_metric: 0.9527 - loss: 0.0408 - val_accuracy: 0.9651 - val_dice_coefficient: 0.8809 - val_iou_metric: 0.7898 - val_loss: 0.3937
# Epoch 74/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9935 - dice_coefficient: 0.9754 - iou_metric: 0.9520 - loss: 0.0417 - val_accuracy: 0.9653 - val_dice_coefficient: 0.8810 - val_iou_metric: 0.7900 - val_loss: 0.4218
# Epoch 75/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9936 - dice_coefficient: 0.9758 - iou_metric: 0.9528 - loss: 0.0413 - val_accuracy: 0.9652 - val_dice_coefficient: 0.8805 - val_iou_metric: 0.7891 - val_loss: 0.4130
# Epoch 76/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9936 - dice_coefficient: 0.9753 - iou_metric: 0.9518 - loss: 0.0417 - val_accuracy: 0.9652 - val_dice_coefficient: 0.8800 - val_iou_metric: 0.7883 - val_loss: 0.3990
# Epoch 77/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9940 - dice_coefficient: 0.9772 - iou_metric: 0.9555 - loss: 0.0383 - val_accuracy: 0.9654 - val_dice_coefficient: 0.8806 - val_iou_metric: 0.7893 - val_loss: 0.4088
# Epoch 78/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 219ms/step - accuracy: 0.9939 - dice_coefficient: 0.9769 - iou_metric: 0.9549 - loss: 0.0389 - val_accuracy: 0.9655 - val_dice_coefficient: 0.8825 - val_iou_metric: 0.7923 - val_loss: 0.4180
# Epoch 79/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9941 - dice_coefficient: 0.9774 - iou_metric: 0.9558 - loss: 0.0382 - val_accuracy: 0.9656 - val_dice_coefficient: 0.8824 - val_iou_metric: 0.7922 - val_loss: 0.4268
# Epoch 80/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9939 - dice_coefficient: 0.9768 - iou_metric: 0.9547 - loss: 0.0392 - val_accuracy: 0.9657 - val_dice_coefficient: 0.8822 - val_iou_metric: 0.7918 - val_loss: 0.4297
# Epoch 81/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9942 - dice_coefficient: 0.9781 - iou_metric: 0.9571 - loss: 0.0373 - val_accuracy: 0.9656 - val_dice_coefficient: 0.8817 - val_iou_metric: 0.7910 - val_loss: 0.4280
# Epoch 82/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9940 - dice_coefficient: 0.9775 - iou_metric: 0.9560 - loss: 0.0381 - val_accuracy: 0.9654 - val_dice_coefficient: 0.8814 - val_iou_metric: 0.7905 - val_loss: 0.4148
# Epoch 83/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9942 - dice_coefficient: 0.9778 - iou_metric: 0.9567 - loss: 0.0372 - val_accuracy: 0.9658 - val_dice_coefficient: 0.8813 - val_iou_metric: 0.7905 - val_loss: 0.4215
# Epoch 84/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9942 - dice_coefficient: 0.9774 - iou_metric: 0.9558 - loss: 0.0379 - val_accuracy: 0.9654 - val_dice_coefficient: 0.8820 - val_iou_metric: 0.7916 - val_loss: 0.4259
# Epoch 85/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9941 - dice_coefficient: 0.9773 - iou_metric: 0.9556 - loss: 0.0382 - val_accuracy: 0.9656 - val_dice_coefficient: 0.8819 - val_iou_metric: 0.7913 - val_loss: 0.4322
# Epoch 86/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9943 - dice_coefficient: 0.9786 - iou_metric: 0.9580 - loss: 0.0363 - val_accuracy: 0.9657 - val_dice_coefficient: 0.8825 - val_iou_metric: 0.7923 - val_loss: 0.4174
# Epoch 87/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9945 - dice_coefficient: 0.9792 - iou_metric: 0.9593 - loss: 0.0352 - val_accuracy: 0.9653 - val_dice_coefficient: 0.8803 - val_iou_metric: 0.7889 - val_loss: 0.4532
# Epoch 88/100
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 22s 218ms/step - accuracy: 0.9941 - dice_coefficient: 0.9775 - iou_metric: 0.9560 - loss: 0.0382 - val_accuracy: 0.9659 - val_dice_coefficient: 0.8825 - val_iou_metric: 0.7923 - val_loss: 0.4381

# %%
import matplotlib.pyplot as plt

def plot_metrics(history):
    # Dice
    plt.figure(figsize=(10,4))
    plt.plot(history.history['dice_coefficient'], label='Train Dice')
    plt.plot(history.history['val_dice_coefficient'], label='Val Dice')
    plt.title('Dice Coefficient')
    plt.xlabel('Epoch')
    plt.ylabel('Dice')
    plt.legend()
    plt.show()

    # IoU
    plt.figure(figsize=(10,4))
    plt.plot(history.history['iou_metric'], label='Train IoU')
    plt.plot(history.history['val_iou_metric'], label='Val IoU')
    plt.title('IoU Metric')
    plt.xlabel('Epoch')
    plt.ylabel('IoU')
    plt.legend()
    plt.show()

plot_metrics(history)

# %%
# Load best model
model.load_weights("best_model.h5")

# Evaluate on test set
results = model.evaluate(test_dataset)
print("\nTest Results:")
for name, value in zip(model.metrics_names, results):
    print(f"{name}: {value:.4f}")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9665 - dice_coefficient: 0.8807 - iou_metric: 0.7906 - loss: 0.3968
#
# Test Results:
# loss: 0.3331
# compile_metrics: 0.9706

# %%
import matplotlib.pyplot as plt

def display_predictions(model, dataset, num_samples=5):
    for images, masks in dataset.take(num_samples):
        preds = model.predict(images)
        preds = (preds > 0.5).astype("float32")  # Binarize predictions

        for i in range(len(images)):
            plt.figure(figsize=(12, 4))

            plt.subplot(1, 3, 1)
            plt.title("Input Image")
            plt.imshow(images[i].numpy().squeeze(), cmap="gray")
            plt.axis("off")

            plt.subplot(1, 3, 2)
            plt.title("Ground Truth")
            plt.imshow(masks[i].numpy().squeeze(), cmap="gray")
            plt.axis("off")

            plt.subplot(1, 3, 3)
            plt.title("Prediction")
            plt.imshow(preds[i].squeeze(), cmap="gray")
            plt.axis("off")

            plt.show()

# Show predictions for test samples
display_predictions(model, test_dataset, num_samples=5)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor_128']
# Received: inputs=Tensor(shape=(1, 256, 256, 1))
#   warnings.warn(msg)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 884ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
